# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 616

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&units={units}&q="
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(query_url + city).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']
        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 2 of Set 1 | adamstown
# Processing Record 3 of Set 1 | blackmans bay
# Processing Record 4 of Set 1 | namtsy
# Processing Record 5 of Set 1 | invercargill
# Processing Record 6 of Set 1 | port-aux-francais
# Processing Record 7 of Set 1 | greenwood
# Processing Record 8 of Set 1 | yellowknife
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | hawaiian paradise park
# Processing Record 11 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 12 of Set 1 | tocopilla
# Processing Record 13 of Set 1 | greenville
# Processing Record 14 of Set 1 | malinyi
# Processing Record 15 of Set 1 | vernon
# Processing Record 16 of Set 1 | east london
# Processing Record 17 of Set 1 | sharypovo
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | kapa'a
# Processing Record 20 of Set 1 | edinburgh of the seven seas
# Processing Record 21 of Set 1 | gizo
# Processing Record 22 of Set 1 | tolanaro
# Processing Record 23 of Set 1 | wotho
# Processing Record 24 of Set 1 | port mathurin
# Processing Record 25 of Set 1 | puerto ayora
# Processing Record 26 of Set 1 | luanda
# Processing Record 27 of Set 1 | 'ohonua
# City not found. Skipping...
# Processing Record 28 of Set 1 | bandundu
# Processing Record 29 of Set 1 | boca suno
# Processing Record 30 of Set 1 | pokhara
# Processing Record 31 of Set 1 | port alfred
# Processing Record 32 of Set 1 | waitangi
# Processing Record 33 of Set 1 | hermanus
# Processing Record 34 of Set 1 | badger
# Processing Record 35 of Set 1 | thompson
# Processing Record 36 of Set 1 | west island
# Processing Record 37 of Set 1 | san antonio de pale
# Processing Record 38 of Set 1 | sao felix do xingu
# Processing Record 39 of Set 1 | puerto natales
# Processing Record 40 of Set 1 | tranovaho
# City not found. Skipping...
# Processing Record 41 of Set 1 | khadyzhensk
# Processing Record 42 of Set 1 | betio village
# Processing Record 43 of Set 1 | margaret river
# Processing Record 44 of Set 1 | mossel bay
# Processing Record 45 of Set 1 | cuenca
# Processing Record 46 of Set 1 | tura
# Processing Record 47 of Set 1 | port hueneme
# Processing Record 48 of Set 1 | udachny
# Processing Record 49 of Set 1 | stanley
# Processing Record 50 of Set 1 | kusheriki
# Processing Record 0 of Set 2 | ilulissat
# Processing Record 1 of Set 2 | uzgen
# Processing Record 2 of Set 2 | papatowai
# Processing Record 3 of Set 2 | camabatela
# Processing Record 4 of Set 2 | la passe
# Processing Record 5 of Set 2 | paragominas
# Processing Record 6 of Set 2 | jamestown
# Processing Record 7 of Set 2 | ugoofaaru
# Processing Record 8 of Set 2 | polyarnyy
# Processing Record 9 of Set 2 | novo aripuana
# Processing Record 10 of Set 2 | iskateley
# Processing Record 11 of Set 2 | chernyshevsk
# Processing Record 12 of Set 2 | bhanvad
# Processing Record 13 of Set 2 | qaqortoq
# Processing Record 14 of Set 2 | grytviken
# Processing Record 15 of Set 2 | biltine
# Processing Record 16 of Set 2 | olonkinbyen
# Processing Record 17 of Set 2 | ribeira grande
# Processing Record 18 of Set 2 | ahau
# City not found. Skipping...
# Processing Record 19 of Set 2 | lazaro cardenas
# Processing Record 20 of Set 2 | fonte boa
# Processing Record 21 of Set 2 | vilyuchinsk
# Processing Record 22 of Set 2 | anadyr
# Processing Record 23 of Set 2 | vorgashor
# Processing Record 24 of Set 2 | tadine
# Processing Record 25 of Set 2 | argo
# Processing Record 26 of Set 2 | codrington
# Processing Record 27 of Set 2 | tiksi
# Processing Record 28 of Set 2 | talnakh
# Processing Record 29 of Set 2 | whitehorse
# Processing Record 30 of Set 2 | bilibino
# Processing Record 31 of Set 2 | charlotte amalie
# Processing Record 32 of Set 2 | cabo san lucas
# Processing Record 33 of Set 2 | bethel
# Processing Record 34 of Set 2 | rosarito
# Processing Record 35 of Set 2 | mahina
# Processing Record 36 of Set 2 | nantucket
# Processing Record 37 of Set 2 | longyearbyen
# Processing Record 38 of Set 2 | ar ruways
# Processing Record 39 of Set 2 | fortuna
# Processing Record 40 of Set 2 | bredasdorp
# Processing Record 41 of Set 2 | francisco beltrao
# Processing Record 42 of Set 2 | georgetown
# Processing Record 43 of Set 2 | inari
# Processing Record 44 of Set 2 | bamboo flat
# Processing Record 45 of Set 2 | avarua
# Processing Record 46 of Set 2 | el granada
# Processing Record 47 of Set 2 | klyuchi
# Processing Record 48 of Set 2 | saint-philippe
# Processing Record 49 of Set 2 | nizhnevartovsk
# Processing Record 0 of Set 3 | basco
# Processing Record 1 of Set 3 | vadso
# Processing Record 2 of Set 3 | luderitz
# Processing Record 3 of Set 3 | tibu
# Processing Record 4 of Set 3 | portage la prairie
# Processing Record 5 of Set 3 | ushuaia
# Processing Record 6 of Set 3 | valle de la pascua
# Processing Record 7 of Set 3 | port douglas
# Processing Record 8 of Set 3 | ust-nera
# Processing Record 9 of Set 3 | shubarshi
# Processing Record 10 of Set 3 | wulingyuan
# Processing Record 11 of Set 3 | laguna
# Processing Record 12 of Set 3 | xiaoweizhai
# Processing Record 13 of Set 3 | gadzhiyevo
# Processing Record 14 of Set 3 | lompoc
# Processing Record 15 of Set 3 | sitka
# Processing Record 16 of Set 3 | mamou
# Processing Record 17 of Set 3 | fale old settlement
# Processing Record 18 of Set 3 | iqaluit
# Processing Record 19 of Set 3 | afaahiti
# Processing Record 20 of Set 3 | kodiak
# Processing Record 21 of Set 3 | monrovia
# Processing Record 22 of Set 3 | the pas
# Processing Record 23 of Set 3 | icano
# Processing Record 24 of Set 3 | college
# Processing Record 25 of Set 3 | olonets
# Processing Record 26 of Set 3 | pascagoula
# Processing Record 27 of Set 3 | hithadhoo
# Processing Record 28 of Set 3 | uray
# Processing Record 29 of Set 3 | cidreira
# Processing Record 30 of Set 3 | ruidoso
# Processing Record 31 of Set 3 | yarmouth
# Processing Record 32 of Set 3 | kudahuvadhoo
# Processing Record 33 of Set 3 | axim
# Processing Record 34 of Set 3 | broken hill
# Processing Record 35 of Set 3 | mananara
# Processing Record 36 of Set 3 | weno
# Processing Record 37 of Set 3 | praia da vitoria
# Processing Record 38 of Set 3 | aasiaat
# Processing Record 39 of Set 3 | uturoa
# Processing Record 40 of Set 3 | anna regina
# Processing Record 41 of Set 3 | san patricio
# Processing Record 42 of Set 3 | shimanovsk
# Processing Record 43 of Set 3 | siena
# Processing Record 44 of Set 3 | outapi
# City not found. Skipping...
# Processing Record 45 of Set 3 | peniche
# Processing Record 46 of Set 3 | xai-xai
# Processing Record 47 of Set 3 | happy valley-goose bay
# Processing Record 48 of Set 3 | pitimbu
# Processing Record 49 of Set 3 | zhob
# Processing Record 0 of Set 4 | corato
# Processing Record 1 of Set 4 | karratha
# Processing Record 2 of Set 4 | hamilton
# Processing Record 3 of Set 4 | isafjordur
# Processing Record 4 of Set 4 | harstad
# Processing Record 5 of Set 4 | acarau
# Processing Record 6 of Set 4 | dampit
# Processing Record 7 of Set 4 | gamba
# Processing Record 8 of Set 4 | piti village
# Processing Record 9 of Set 4 | kapuskasing
# Processing Record 10 of Set 4 | coquimbo
# Processing Record 11 of Set 4 | naze
# Processing Record 12 of Set 4 | gueltat zemmour
# City not found. Skipping...
# Processing Record 13 of Set 4 | byron bay
# Processing Record 14 of Set 4 | port elizabeth
# Processing Record 15 of Set 4 | alofi
# Processing Record 16 of Set 4 | borogontsy
# Processing Record 17 of Set 4 | tororo
# Processing Record 18 of Set 4 | pulpi
# Processing Record 19 of Set 4 | kargasok
# Processing Record 20 of Set 4 | bahar
# Processing Record 21 of Set 4 | port saint john's
# Processing Record 22 of Set 4 | antonio enes
# Processing Record 23 of Set 4 | chifeng
# Processing Record 24 of Set 4 | le lavandou
# Processing Record 25 of Set 4 | atafu village
# Processing Record 26 of Set 4 | nova sintra
# Processing Record 27 of Set 4 | debre tabor
# Processing Record 28 of Set 4 | sao joao da barra
# Processing Record 29 of Set 4 | hammerfest
# Processing Record 30 of Set 4 | saipan
# Processing Record 31 of Set 4 | sullana
# Processing Record 32 of Set 4 | queenstown
# Processing Record 33 of Set 4 | azadshahr
# Processing Record 34 of Set 4 | flying fish cove
# Processing Record 35 of Set 4 | luau
# Processing Record 36 of Set 4 | saldanha
# Processing Record 37 of Set 4 | de soto
# Processing Record 38 of Set 4 | manthani
# Processing Record 39 of Set 4 | bowen
# Processing Record 40 of Set 4 | ciudad tula
# Processing Record 41 of Set 4 | baniyas
# Processing Record 42 of Set 4 | st. john's
# Processing Record 43 of Set 4 | tan-tan
# Processing Record 44 of Set 4 | quellon
# Processing Record 45 of Set 4 | grao de murviedro
# Processing Record 46 of Set 4 | bafoulabe
# Processing Record 47 of Set 4 | sanctuary point
# Processing Record 48 of Set 4 | yuzhno-kurilsk
# Processing Record 49 of Set 4 | kyzyl-mazhalyk
# Processing Record 0 of Set 5 | thurso
# Processing Record 1 of Set 5 | morehead city
# Processing Record 2 of Set 5 | ancud
# Processing Record 3 of Set 5 | sheridan
# Processing Record 4 of Set 5 | yemva
# Processing Record 5 of Set 5 | hukumati azrah
# Processing Record 6 of Set 5 | punta cardon
# Processing Record 7 of Set 5 | yuanping
# Processing Record 8 of Set 5 | ciudad lazaro cardenas
# Processing Record 9 of Set 5 | ust'-ilimsk
# Processing Record 10 of Set 5 | mata-utu
# Processing Record 11 of Set 5 | chos malal
# Processing Record 12 of Set 5 | zyryanskoye
# Processing Record 13 of Set 5 | porto novo
# Processing Record 14 of Set 5 | alice springs
# Processing Record 15 of Set 5 | isangel
# Processing Record 16 of Set 5 | ola
# Processing Record 17 of Set 5 | chauk
# Processing Record 18 of Set 5 | machico
# Processing Record 19 of Set 5 | afif
# Processing Record 20 of Set 5 | new norfolk
# Processing Record 21 of Set 5 | baharly
# Processing Record 22 of Set 5 | chonchi
# Processing Record 23 of Set 5 | chibougamau
# Processing Record 24 of Set 5 | waddan
# Processing Record 25 of Set 5 | gondar
# Processing Record 26 of Set 5 | omaruru
# Processing Record 27 of Set 5 | gisborne
# Processing Record 28 of Set 5 | anapa
# Processing Record 29 of Set 5 | wailua homesteads
# Processing Record 30 of Set 5 | praia
# Processing Record 31 of Set 5 | al hufuf
# Processing Record 32 of Set 5 | tsiombe
# Processing Record 33 of Set 5 | carutapera
# Processing Record 34 of Set 5 | i-n-salah
# Processing Record 35 of Set 5 | guiratinga
# Processing Record 36 of Set 5 | galesong
# Processing Record 37 of Set 5 | marsh harbour
# Processing Record 38 of Set 5 | chengde
# Processing Record 39 of Set 5 | sao gabriel da cachoeira
# Processing Record 40 of Set 5 | aykhal
# Processing Record 41 of Set 5 | puerto carreno
# Processing Record 42 of Set 5 | severo-yeniseyskiy
# Processing Record 43 of Set 5 | kinmparana
# Processing Record 44 of Set 5 | ceelbuur
# Processing Record 45 of Set 5 | inhambane
# Processing Record 46 of Set 5 | bardsir
# Processing Record 47 of Set 5 | kodinar
# Processing Record 48 of Set 5 | jalai nur
# Processing Record 49 of Set 5 | arraial do cabo
# Processing Record 0 of Set 6 | constantia
# Processing Record 1 of Set 6 | itoman
# Processing Record 2 of Set 6 | chernyshevskiy
# Processing Record 3 of Set 6 | abepura
# Processing Record 4 of Set 6 | brookings
# Processing Record 5 of Set 6 | garoowe
# Processing Record 6 of Set 6 | uglegorsk
# Processing Record 7 of Set 6 | flin flon
# Processing Record 8 of Set 6 | burang
# Processing Record 9 of Set 6 | itaituba
# Processing Record 10 of Set 6 | keflavik
# Processing Record 11 of Set 6 | sabang
# Processing Record 12 of Set 6 | reggane
# Processing Record 13 of Set 6 | sydney mines
# Processing Record 14 of Set 6 | portland
# Processing Record 15 of Set 6 | corn island
# Processing Record 16 of Set 6 | ilomantsi
# Processing Record 17 of Set 6 | ginir
# Processing Record 18 of Set 6 | ghadamis
# Processing Record 19 of Set 6 | chiniot
# Processing Record 20 of Set 6 | el calafate
# Processing Record 21 of Set 6 | nemuro
# Processing Record 22 of Set 6 | keskin
# Processing Record 23 of Set 6 | ikwiriri
# Processing Record 24 of Set 6 | baruun-urt
# Processing Record 25 of Set 6 | tateyama
# Processing Record 26 of Set 6 | chamical
# Processing Record 27 of Set 6 | kalmunai
# Processing Record 28 of Set 6 | cabedelo
# Processing Record 29 of Set 6 | lagoa
# Processing Record 30 of Set 6 | cambria
# Processing Record 31 of Set 6 | trincomalee
# Processing Record 32 of Set 6 | taltal
# Processing Record 33 of Set 6 | walvis bay
# Processing Record 34 of Set 6 | ntungamo
# Processing Record 35 of Set 6 | yelizovo
# Processing Record 36 of Set 6 | kralendijk
# Processing Record 37 of Set 6 | dudinka
# Processing Record 38 of Set 6 | hasaki
# Processing Record 39 of Set 6 | jayapura
# Processing Record 40 of Set 6 | nuku'alofa
# Processing Record 41 of Set 6 | aldinga beach
# Processing Record 42 of Set 6 | auki
# Processing Record 43 of Set 6 | bovril
# Processing Record 44 of Set 6 | khandyga
# Processing Record 45 of Set 6 | sao geraldo do araguaia
# Processing Record 46 of Set 6 | la paz
# Processing Record 47 of Set 6 | taroa
# Processing Record 48 of Set 6 | xinzhi
# Processing Record 49 of Set 6 | niamey
# Processing Record 0 of Set 7 | kataragama
# City not found. Skipping...
# Processing Record 1 of Set 7 | nova vicosa
# Processing Record 2 of Set 7 | macouria
# Processing Record 3 of Set 7 | umluj
# Processing Record 4 of Set 7 | hecun
# Processing Record 5 of Set 7 | dalnegorsk
# Processing Record 6 of Set 7 | mabaruma
# Processing Record 7 of Set 7 | el-tor
# Processing Record 8 of Set 7 | puerto baquerizo moreno
# Processing Record 9 of Set 7 | greymouth
# Processing Record 10 of Set 7 | hadibu
# Processing Record 11 of Set 7 | sao vicente
# Processing Record 12 of Set 7 | okhotsk
# Processing Record 13 of Set 7 | yatou
# Processing Record 14 of Set 7 | karaton
# Processing Record 15 of Set 7 | vingt cinq
# City not found. Skipping...
# Processing Record 16 of Set 7 | malangas
# Processing Record 17 of Set 7 | lianran
# Processing Record 18 of Set 7 | sandnessjoen
# Processing Record 19 of Set 7 | klin
# Processing Record 20 of Set 7 | al ghayzah
# Processing Record 21 of Set 7 | shijiazhuang
# Processing Record 22 of Set 7 | waimea
# Processing Record 23 of Set 7 | lihue
# Processing Record 24 of Set 7 | tezu
# Processing Record 25 of Set 7 | boende
# Processing Record 26 of Set 7 | bukoba
# Processing Record 27 of Set 7 | fukuecho
# Processing Record 28 of Set 7 | margate
# Processing Record 29 of Set 7 | loiza
# Processing Record 30 of Set 7 | santa cruz
# Processing Record 31 of Set 7 | an nuhud
# Processing Record 32 of Set 7 | holualoa
# Processing Record 33 of Set 7 | aegina
# Processing Record 34 of Set 7 | suva
# Processing Record 35 of Set 7 | mwinilunga
# Processing Record 36 of Set 7 | northam
# Processing Record 37 of Set 7 | kuta
# Processing Record 38 of Set 7 | velika obarska
# Processing Record 39 of Set 7 | lusaka
# Processing Record 40 of Set 7 | balqash
# Processing Record 41 of Set 7 | xichang
# Processing Record 42 of Set 7 | klaksvik
# Processing Record 43 of Set 7 | puerto real
# Processing Record 44 of Set 7 | boda
# Processing Record 45 of Set 7 | la junta
# Processing Record 46 of Set 7 | malango
# Processing Record 47 of Set 7 | al jahra'
# Processing Record 48 of Set 7 | rawah
# Processing Record 49 of Set 7 | fortaleza
# Processing Record 0 of Set 8 | rabaul
# Processing Record 1 of Set 8 | ta`u
# Processing Record 2 of Set 8 | colonia
# Processing Record 3 of Set 8 | san pedro pochutla
# Processing Record 4 of Set 8 | vershino-darasunskiy
# Processing Record 5 of Set 8 | mukah
# City not found. Skipping...
# Processing Record 6 of Set 8 | segezha
# Processing Record 7 of Set 8 | laayoune plage
# City not found. Skipping...
# Processing Record 8 of Set 8 | gurupi
# Processing Record 9 of Set 8 | yaren
# Processing Record 10 of Set 8 | saint-joseph
# Processing Record 11 of Set 8 | honcho
# Processing Record 12 of Set 8 | mermoz boabab
# Processing Record 13 of Set 8 | fuglafjordur
# Processing Record 14 of Set 8 | zhuanghe
# Processing Record 15 of Set 8 | minas de marcona
# Processing Record 16 of Set 8 | libertad
# Processing Record 17 of Set 8 | hilo
# Processing Record 18 of Set 8 | lycksele
# Processing Record 19 of Set 8 | serenje
# Processing Record 20 of Set 8 | gunnedah
# Processing Record 21 of Set 8 | ciudad del carmen
# Processing Record 22 of Set 8 | natal
# Processing Record 23 of Set 8 | kaifeng
# Processing Record 24 of Set 8 | yigo village
# Processing Record 25 of Set 8 | mangalia
# Processing Record 26 of Set 8 | kouroussa
# Processing Record 27 of Set 8 | nizhnesortymskiy
# Processing Record 28 of Set 8 | tambovka
# Processing Record 29 of Set 8 | kurchum
# Processing Record 30 of Set 8 | saint-henri
# Processing Record 31 of Set 8 | tynda
# Processing Record 32 of Set 8 | bathsheba
# Processing Record 33 of Set 8 | fort bragg
# Processing Record 34 of Set 8 | celestun
# Processing Record 35 of Set 8 | fisterra
# Processing Record 36 of Set 8 | puerto san jose
# Processing Record 37 of Set 8 | wamba
# Processing Record 38 of Set 8 | awjilah
# Processing Record 39 of Set 8 | berdigestyakh
# Processing Record 40 of Set 8 | menongue
# Processing Record 41 of Set 8 | geraldton
# Processing Record 42 of Set 8 | viedma
# Processing Record 43 of Set 8 | mogadishu
# Processing Record 44 of Set 8 | songea
# Processing Record 45 of Set 8 | tazovsky
# Processing Record 46 of Set 8 | porangatu
# Processing Record 47 of Set 8 | novyy karanlug
# Processing Record 48 of Set 8 | zyryanovsk
# Processing Record 49 of Set 8 | horta
# Processing Record 0 of Set 9 | mitu
# Processing Record 1 of Set 9 | kencong
# Processing Record 2 of Set 9 | jasim
# Processing Record 3 of Set 9 | puerto san carlos
# City not found. Skipping...
# Processing Record 4 of Set 9 | illintsi
# Processing Record 5 of Set 9 | paphos
# Processing Record 6 of Set 9 | port shepstone
# Processing Record 7 of Set 9 | uliastay
# Processing Record 8 of Set 9 | vila velha
# Processing Record 9 of Set 9 | nalut
# Processing Record 10 of Set 9 | pattani
# Processing Record 11 of Set 9 | port maria
# Processing Record 12 of Set 9 | mikuni
# Processing Record 13 of Set 9 | labytnangi
# Processing Record 14 of Set 9 | banda aceh
# Processing Record 15 of Set 9 | mao
# Processing Record 16 of Set 9 | mount isa
# Processing Record 17 of Set 9 | dul'durga
# Processing Record 18 of Set 9 | arba minch
# Processing Record 19 of Set 9 | castillos
# Processing Record 20 of Set 9 | dowlatabad
# Processing Record 21 of Set 9 | ouadda
# Processing Record 22 of Set 9 | tukrah
# Processing Record 23 of Set 9 | aleshtar
# Processing Record 24 of Set 9 | bereznik
# Processing Record 25 of Set 9 | korla
# Processing Record 26 of Set 9 | daru
# Processing Record 27 of Set 9 | kill devil hills
# Processing Record 28 of Set 9 | badnawar
# Processing Record 29 of Set 9 | winnemucca
# Processing Record 30 of Set 9 | ouani
# Processing Record 31 of Set 9 | xunchang
# Processing Record 32 of Set 9 | stephenville
# Processing Record 33 of Set 9 | ayutla de los libres
# Processing Record 34 of Set 9 | susuman
# Processing Record 35 of Set 9 | kyzyl-kyya
# Processing Record 36 of Set 9 | tambopata
# Processing Record 37 of Set 9 | pisco
# Processing Record 38 of Set 9 | kanniyakumari
# Processing Record 39 of Set 9 | port macquarie
# Processing Record 40 of Set 9 | antsiranana
# Processing Record 41 of Set 9 | maintirano
# Processing Record 42 of Set 9 | las lomitas
# Processing Record 43 of Set 9 | la'ie
# Processing Record 44 of Set 9 | bonthe
# Processing Record 45 of Set 9 | moranbah
# Processing Record 46 of Set 9 | soria
# Processing Record 47 of Set 9 | leongatha
# Processing Record 48 of Set 9 | caibiran
# Processing Record 49 of Set 9 | malpica
# Processing Record 0 of Set 10 | howard springs
# Processing Record 1 of Set 10 | ovalle
# Processing Record 2 of Set 10 | hastings
# Processing Record 3 of Set 10 | kingston
# Processing Record 4 of Set 10 | remire-montjoly
# Processing Record 5 of Set 10 | gaigeturi
# Processing Record 6 of Set 10 | selfoss
# Processing Record 7 of Set 10 | jolo
# Processing Record 8 of Set 10 | harper
# Processing Record 9 of Set 10 | cable beach
# City not found. Skipping...
# Processing Record 10 of Set 10 | constitucion
# Processing Record 11 of Set 10 | bardai
# Processing Record 12 of Set 10 | enewetak
# Processing Record 13 of Set 10 | mena
# Processing Record 14 of Set 10 | sovetskaya gavan'
# Processing Record 15 of Set 10 | tamanrasset
# Processing Record 16 of Set 10 | alagapuram
# Processing Record 17 of Set 10 | pushkinskiye gory
# Processing Record 18 of Set 10 | mount gambier
# Processing Record 19 of Set 10 | masterton
# Processing Record 20 of Set 10 | hami
# Processing Record 21 of Set 10 | kourou
# Processing Record 22 of Set 10 | utrik
# Processing Record 23 of Set 10 | port glaud
# City not found. Skipping...
# Processing Record 24 of Set 10 | yushu
# Processing Record 25 of Set 10 | priargunsk
# Processing Record 26 of Set 10 | jinchang
# Processing Record 27 of Set 10 | kulia village
# City not found. Skipping...
# Processing Record 28 of Set 10 | cookeville
# Processing Record 29 of Set 10 | newman
# Processing Record 30 of Set 10 | ratnagiri
# Processing Record 31 of Set 10 | markovo
# Processing Record 32 of Set 10 | whyalla stuart
# City not found. Skipping...
# Processing Record 33 of Set 10 | taulaga
# Processing Record 34 of Set 10 | am djarass
# City not found. Skipping...
# Processing Record 35 of Set 10 | saint-francois
# Processing Record 36 of Set 10 | neftcala
# Processing Record 37 of Set 10 | manjeshvar
# Processing Record 38 of Set 10 | shache
# Processing Record 39 of Set 10 | vikulovo
# Processing Record 40 of Set 10 | alaghsas
# Processing Record 41 of Set 10 | covington
# Processing Record 42 of Set 10 | carnarvon
# Processing Record 43 of Set 10 | qamdo
# Processing Record 44 of Set 10 | rawson
# Processing Record 45 of Set 10 | kas
# Processing Record 46 of Set 10 | sihanoukville
# Processing Record 47 of Set 10 | wanning
# Processing Record 48 of Set 10 | taounate
# Processing Record 49 of Set 10 | ocean pointe
# City not found. Skipping...
# Processing Record 0 of Set 11 | hirara
# Processing Record 1 of Set 11 | nelson bay
# Processing Record 2 of Set 11 | shenjiamen
# Processing Record 3 of Set 11 | tofol
# Processing Record 4 of Set 11 | nanao
# Processing Record 5 of Set 11 | khorixas
# Processing Record 6 of Set 11 | moab
# Processing Record 7 of Set 11 | kavaratti
# Processing Record 8 of Set 11 | cargados carajos
# City not found. Skipping...
# Processing Record 9 of Set 11 | dubovskoye
# Processing Record 10 of Set 11 | slave lake
# Processing Record 11 of Set 11 | novokorsunskaya
# Processing Record 12 of Set 11 | strezhevoy
# Processing Record 13 of Set 11 | livingston
# Processing Record 14 of Set 11 | haiku-pauwela
# Processing Record 15 of Set 11 | boa vista
# Processing Record 16 of Set 11 | belogorsk
# Processing Record 17 of Set 11 | feijo
# Processing Record 18 of Set 11 | boksitogorsk
# Processing Record 19 of Set 11 | kozhikode
# Processing Record 20 of Set 11 | babu
# Processing Record 21 of Set 11 | fada
# Processing Record 22 of Set 11 | glace bay
# Processing Record 23 of Set 11 | vega de alatorre
# Processing Record 24 of Set 11 | san mariano
# Processing Record 25 of Set 11 | xining
# Processing Record 26 of Set 11 | umm kaddadah
# Processing Record 27 of Set 11 | abnub
# Processing Record 28 of Set 11 | laojunmiao
# Processing Record 29 of Set 11 | coahuayana de hidalgo
# Processing Record 30 of Set 11 | dar naim
# City not found. Skipping...
# Processing Record 31 of Set 11 | kiama
# Processing Record 32 of Set 11 | wakkanai
# Processing Record 33 of Set 11 | manado
# Processing Record 34 of Set 11 | aleg
# Processing Record 35 of Set 11 | arkhangel'sk
# Processing Record 36 of Set 11 | caleta olivia
# Processing Record 37 of Set 11 | toliara
# Processing Record 38 of Set 11 | bokhan
# Processing Record 39 of Set 11 | mizdah
# Processing Record 40 of Set 11 | dokkum
# Processing Record 41 of Set 11 | at taj
# Processing Record 42 of Set 11 | touros
# Processing Record 43 of Set 11 | prado
# Processing Record 44 of Set 11 | vuktyl
# Processing Record 45 of Set 11 | chenghua
# Processing Record 46 of Set 11 | sao lourenco da serra
# Processing Record 47 of Set 11 | bokovskaya
# Processing Record 48 of Set 11 | cooper's town
# Processing Record 49 of Set 11 | mstsislaw
# Processing Record 0 of Set 12 | kerben
# Processing Record 1 of Set 12 | ingeniero jacobacci
# Processing Record 2 of Set 12 | kupang
# Processing Record 3 of Set 12 | caleta de carquin
# Processing Record 4 of Set 12 | bilajer
# Processing Record 5 of Set 12 | lethem
# Processing Record 6 of Set 12 | launceston
# Processing Record 7 of Set 12 | moussoro
# Processing Record 8 of Set 12 | tanjung pinang
# Processing Record 9 of Set 12 | rio negro
# Processing Record 10 of Set 12 | urengoy
# Processing Record 11 of Set 12 | fuxin
# Processing Record 12 of Set 12 | nieuw amsterdam
# Processing Record 13 of Set 12 | mejit
# Processing Record 14 of Set 12 | illizi
# Processing Record 15 of Set 12 | dunedin
# Processing Record 16 of Set 12 | sinabang
# Processing Record 17 of Set 12 | tacuarembo
# Processing Record 18 of Set 12 | sogndal
# Processing Record 19 of Set 12 | galliano
# Processing Record 20 of Set 12 | takamaka
# City not found. Skipping...
# Processing Record 21 of Set 12 | mohammedia
# Processing Record 22 of Set 12 | oodweyne
# Processing Record 23 of Set 12 | amarante do maranhao
# Processing Record 24 of Set 12 | chabahar
# Processing Record 25 of Set 12 | kampung pasir gudang baru
# Processing Record 26 of Set 12 | shurugwi
# Processing Record 27 of Set 12 | whakatane
# Processing Record 28 of Set 12 | macau
# Processing Record 29 of Set 12 | nangomba
# Processing Record 30 of Set 12 | al muwayh
# Processing Record 31 of Set 12 | lincoln city
# Processing Record 32 of Set 12 | chkalovsk
# Processing Record 33 of Set 12 | kimbe
# Processing Record 34 of Set 12 | letlhakane
# Processing Record 35 of Set 12 | nuuk
# Processing Record 36 of Set 12 | aswan
# Processing Record 37 of Set 12 | batticaloa
# Processing Record 38 of Set 12 | kasongo
# Processing Record 39 of Set 12 | kristiansund
# Processing Record 40 of Set 12 | santa elena de uairen
# Processing Record 41 of Set 12 | brisas de zicatela
# Processing Record 42 of Set 12 | al kut
# Processing Record 43 of Set 12 | cestos city
# Processing Record 44 of Set 12 | city of balikpapan
# Processing Record 45 of Set 12 | catalhoyuk
# Processing Record 46 of Set 12 | tabou
# Processing Record 47 of Set 12 | farah
# Processing Record 48 of Set 12 | bel ombre
# Processing Record 49 of Set 12 | shani
# Processing Record 0 of Set 13 | praya
# Processing Record 1 of Set 13 | tatvan
# Processing Record 2 of Set 13 | bolszewo
# Processing Record 3 of Set 13 | beloyarskiy
# Processing Record 4 of Set 13 | pameungpeuk
# Processing Record 5 of Set 13 | jaguey grande
# Processing Record 6 of Set 13 | homer
# Processing Record 7 of Set 13 | east ballina
# Processing Record 8 of Set 13 | san luis de la loma
# Processing Record 9 of Set 13 | devils lake
# Processing Record 10 of Set 13 | chicoana
# Processing Record 11 of Set 13 | gornozavodsk
# Processing Record 12 of Set 13 | kirakira
# Processing Record 13 of Set 13 | carbonear
# Processing Record 14 of Set 13 | garissa
# Processing Record 15 of Set 13 | sezanne
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          596
# Lat           596
# Lng           596
# Max Temp      596
# Humidity      596
# Cloudiness    596
# Wind Speed    596
# Country       596
# Date          596
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                        City      Lat       Lng  Max Temp  Humidity  \
# 0  petropavlovsk-kamchatsky  53.0452  158.6483     22.33        60
# 1                 adamstown -25.0660 -130.1015     20.94        67
# 2             blackmans bay -43.0167  147.3167     10.96        78
# 3                    namtsy  62.7161  129.6658     26.21        40
# 4              invercargill -46.4000  168.3500      9.16        78
#
#    Cloudiness  Wind Speed Country        Date
# 0          20        5.00      RU  1688436982
# 1          12        4.02      PN  1688437146
# 2         100        0.25      AU  1688437146
# 3          70        5.12      RU  1688437146
# 4          80        8.64      NZ  1688437146

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                              City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0        petropavlovsk-kamchatsky  53.0452  158.6483     22.33        60
# 1                       adamstown -25.0660 -130.1015     20.94        67
# 2                   blackmans bay -43.0167  147.3167     10.96        78
# 3                          namtsy  62.7161  129.6658     26.21        40
# 4                    invercargill -46.4000  168.3500      9.16        78
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                20        5.00      RU  1688436982
# 1                12        4.02      PN  1688437146
# 2               100        0.25      AU  1688437146
# 3                70        5.12      RU  1688437146
# 4                80        8.64      NZ  1688437146

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'], marker='o', edgecolor='black')

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title("City Latitude vs. Max Temperature (2023-07-03)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Figure1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build scatter plot for latitude vs. humidity
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'], marker='o', edgecolor='black')

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs. Humidity (2023-07-03)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Figure2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build scatter plot for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], marker='o', edgecolor='black')

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs. Cloudiness (2023-07-03)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Figure3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], marker='o', edgecolor='black')

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title("City Latitude vs. Wind Speed (2023-07-03)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Figure4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE
x_values = city_data_df['Lat']
y_values = city_data_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

# %%
northern_hemi_df = city_data_df.loc[(city_data_df['Lat'] >= 0)]
northern_hemi_df.head()
# Out:
#                              City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0        petropavlovsk-kamchatsky  53.0452  158.6483     22.33        60
# 3                          namtsy  62.7161  129.6658     26.21        40
# 6                       greenwood  34.1668  -82.1165     27.82        82
# 7                     yellowknife  62.4560 -114.3525     21.29        28
# 8                          albany  42.6001  -73.9662     21.68        93
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                20        5.00      RU  1688436982
# 3                70        5.12      RU  1688437146
# 6                 0        2.57      US  1688436865
# 7                20        3.09      CA  1688437146
# 8                78        0.61      US  1688436939

# %%
southern_hemi_df = city_data_df.loc[(city_data_df['Lat'] < 0)]
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1                adamstown -25.0660 -130.1015     20.94        67          12
# 2            blackmans bay -43.0167  147.3167     10.96        78         100
# 4             invercargill -46.4000  168.3500      9.16        78          80
# 5        port-aux-francais -49.3500   70.2167      3.04        64          87
# 10               tocopilla -22.0920  -70.1979     17.76        71           2
#
#          Wind Speed Country        Date
# City_ID
# 1              4.02      PN  1688437146
# 2              0.25      AU  1688437146
# 4              8.64      NZ  1688437146
# 5             16.08      TF  1688437146
# 10             2.60      CL  1688437147

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat'].astype('float')
y_values = northern_hemi_df['Max Temp'].astype('float')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

# Plot scatter plot
plt.scatter(x_values, y_values)

# Plot regression line
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq, (5, 10), fontsize = 15, color="red")
# Label plot
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')

# Print r square value
print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# The r-value is: 0.3677569575030464

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat'].astype('float')
y_values = southern_hemi_df['Max Temp'].astype('float')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

# Plot scatter plot
plt.scatter(x_values, y_values)

# Plot regression line
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq, (-50, 30), fontsize = 15, color="red")
# Label plot
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')

# Print r square value
print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# The r-value is: 0.6399369515576067

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat'].astype('float')
y_values = northern_hemi_df['Humidity'].astype('float')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

# Plot scatter plot
plt.scatter(x_values, y_values)

# Plot regression line
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq, (5, 10), fontsize = 15, color="red")
# Label plot
plt.xlabel('Latitude')
plt.ylabel('Humidity')

# Print r square value
print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# The r-value is: 0.009958594961857385

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat'].astype('float')
y_values = southern_hemi_df['Humidity'].astype('float')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

# Plot scatter plot
plt.scatter(x_values, y_values)

# Plot regression line
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq, (-50, 30), fontsize = 15, color="red")
# Label plot
plt.xlabel('Latitude')
plt.ylabel('Humidity')

# Print r square value
print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# The r-value is: 0.007316442498853283

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat'].astype('float')
y_values = northern_hemi_df['Cloudiness'].astype('float')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

# Plot scatter plot
plt.scatter(x_values, y_values)

# Plot regression line
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq, (40, 10), fontsize = 15, color="red")
# Label plot
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

# Print r square value
print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# The r-value is: 0.02497400080607877

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat'].astype('float')
y_values = southern_hemi_df['Cloudiness'].astype('float')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

# Plot scatter plot
plt.scatter(x_values, y_values)

# Plot regression line
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq, (-50, 30), fontsize = 15, color="red")
# Label plot
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

# Print r square value
print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# The r-value is: 0.023649480957405516

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat'].astype('float')
y_values = northern_hemi_df['Wind Speed'].astype('float')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

# Plot scatter plot
plt.scatter(x_values, y_values)

# Plot regression line
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq, (5, 10), fontsize = 15, color="red")
# Label plot
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')

# Print r square value
print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# The r-value is: 0.0032075292051071476

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat'].astype('float')
y_values = southern_hemi_df['Wind Speed'].astype('float')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

# Plot scatter plot
plt.scatter(x_values, y_values)

# Plot regression line
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq, (-50, 12), fontsize = 15, color="red")
# Label plot
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')

# Print r square value
print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# The r-value is: 0.015015345443218926

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
